# %%
# !pip install opencv-python
# !pip install matplotlib
# !pip install numpy
# Out:
# Requirement already satisfied: opencv-python in c:\users\jines\anaconda3\lib\site-packages (4.7.0.68)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\jines\anaconda3\lib\site-packages (from opencv-python) (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\jines\anaconda3\lib\site-packages (3.5.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\jines\anaconda3\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\jines\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jines\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jines\anaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\jines\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jines\anaconda3\lib\site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\jines\anaconda3\lib\site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jines\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\jines\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: numpy in c:\users\jines\anaconda3\lib\site-packages (1.21.5)

# %%
# !pip install torch==1.7.1+cpu torchvision==0.8.2+cpu torchaudio===0.7.2 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install easyocr
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Requirement already satisfied: torch==1.7.1+cpu in c:\users\jines\anaconda3\lib\site-packages (1.7.1+cpu)
# Requirement already satisfied: torchvision==0.8.2+cpu in c:\users\jines\anaconda3\lib\site-packages (0.8.2+cpu)
# Requirement already satisfied: torchaudio===0.7.2 in c:\users\jines\anaconda3\lib\site-packages (0.7.2)
# Requirement already satisfied: typing-extensions in c:\users\jines\anaconda3\lib\site-packages (from torch==1.7.1+cpu) (4.4.0)
# Requirement already satisfied: numpy in c:\users\jines\anaconda3\lib\site-packages (from torch==1.7.1+cpu) (1.21.5)
# Requirement already satisfied: pillow>=4.1.1 in c:\users\jines\anaconda3\lib\site-packages (from torchvision==0.8.2+cpu) (9.3.0)
# Requirement already satisfied: easyocr in c:\users\jines\anaconda3\lib\site-packages (1.6.2)
# Requirement already satisfied: numpy in c:\users\jines\anaconda3\lib\site-packages (from easyocr) (1.21.5)
# Requirement already satisfied: Pillow in c:\users\jines\anaconda3\lib\site-packages (from easyocr) (9.3.0)
# Requirement already satisfied: scipy in c:\users\jines\anaconda3\lib\site-packages (from easyocr) (1.8.1)
# Requirement already satisfied: scikit-image in c:\users\jines\anaconda3\lib\site-packages (from easyocr) (0.19.3)
# Requirement already satisfied: PyYAML in c:\users\jines\anaconda3\lib\site-packages (from easyocr) (6.0)
# Requirement already satisfied: pyclipper in c:\users\jines\anaconda3\lib\site-packages (from easyocr) (1.3.0.post4)
# Requirement already satisfied: python-bidi in c:\users\jines\anaconda3\lib\site-packages (from easyocr) (0.4.2)
# Requirement already satisfied: torchvision>=0.5 in c:\users\jines\anaconda3\lib\site-packages (from easyocr) (0.8.2+cpu)
# Requirement already satisfied: ninja in c:\users\jines\anaconda3\lib\site-packages (from easyocr) (1.11.1)
# Requirement already satisfied: torch in c:\users\jines\anaconda3\lib\site-packages (from easyocr) (1.7.1+cpu)
# Requirement already satisfied: Shapely in c:\users\jines\anaconda3\lib\site-packages (from easyocr) (2.0.1)
# Requirement already satisfied: opencv-python-headless<=4.5.4.60 in c:\users\jines\anaconda3\lib\site-packages (from easyocr) (4.5.4.60)
# Requirement already satisfied: typing-extensions in c:\users\jines\anaconda3\lib\site-packages (from torch->easyocr) (4.4.0)
# Requirement already satisfied: six in c:\users\jines\anaconda3\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\jines\anaconda3\lib\site-packages (from scikit-image->easyocr) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\jines\anaconda3\lib\site-packages (from scikit-image->easyocr) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\jines\anaconda3\lib\site-packages (from scikit-image->easyocr) (23.0)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\jines\anaconda3\lib\site-packages (from scikit-image->easyocr) (2.19.3)
# Requirement already satisfied: networkx>=2.2 in c:\users\jines\anaconda3\lib\site-packages (from scikit-image->easyocr) (2.5.1)
# Requirement already satisfied: decorator<5,>=4.3 in c:\users\jines\anaconda3\lib\site-packages (from networkx>=2.2->scikit-image->easyocr) (4.4.2)

# %%
import cv2
import numpy as np
import easyocr
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
im_1_path = 'D:/mlai/carplate.jfif'
im_2_path = 'D:/mlai/image_digit.jfif'

# %%
def recognize_text(img_path):
    '''loads an image and recognizes text.'''
    
    reader = easyocr.Reader(['en'])
    return reader.readtext(img_path)

# %%
result = recognize_text(im_1_path)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
result
# Out:
# [([[93, 119], [147, 119], [147, 135], [93, 135]],
#   'CCC444',
#   0.5561226550152698)]

# %%
img_1 = cv2.imread(im_1_path)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)
plt.imshow(img_1)

# %%
img_2 = cv2.imread(im_2_path)
img_2 = cv2.cvtColor(img_2, cv2.COLOR_BGR2RGB)
plt.imshow(img_2)

# %%
def overlay_ocr_text(img_path, save_name):
    '''loads an image, recognizes text, and overlays the text on the image.'''
    
    # loads image
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    dpi = 5
    fig_width, fig_height = int(img.shape[0]/dpi), int(img.shape[1]/dpi)
    plt.figure()
    f, axarr = plt.subplots(1,2, figsize=(fig_width, fig_height)) 
    axarr[0].imshow(img)
    
    # recognize text
    result = recognize_text(img_path)

    # if OCR prob is over 0.5, overlay bounding box and text
    for (bbox, text, prob) in result:
        if prob >= 0.5:
            # display 
            print(f'Detected text: {text} (Probability: {prob:.2f})')

            # get top-left and bottom-right bbox vertices
            (top_left, top_right, bottom_right, bottom_left) = bbox
            top_left = (int(top_left[0]), int(top_left[1]))
            bottom_right = (int(bottom_right[0]), int(bottom_right[1]))

            # create a rectangle for bbox display
            cv2.rectangle(img=img, pt1=top_left, pt2=bottom_right, color=(255, 0, 0), thickness=10)

            # put recognized text
            cv2.putText(img=img, text=text, org=(top_left[0], top_left[1] - 10), fontFace=cv2.FONT_HERSHEY_SIMPLEX, fontScale=1, color=(255, 0, 0), thickness=8)
        
    # show and save image
    axarr[1].imshow(img)
    plt.savefig(f'D:/mlai/output/{save_name}_overlay.jpg', bbox_inches='tight')

# %%
overlay_ocr_text(im_1_path, 'carplate')
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# Detected text: CCC444 (Probability: 0.56)

# %%
overlay_ocr_text(im_3_path, 'digits')
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# Detected text: 5 (Probability: 1.00)

# %% [markdown]
# # Text-to-speech recognition

# %%
# !pip install pyttsx3
# Out:
# Requirement already satisfied: pyttsx3 in c:\users\jines\anaconda3\lib\site-packages (2.90)
# Requirement already satisfied: pypiwin32 in c:\users\jines\anaconda3\lib\site-packages (from pyttsx3) (223)
# Requirement already satisfied: pywin32 in c:\users\jines\anaconda3\lib\site-packages (from pyttsx3) (305.1)
# Requirement already satisfied: comtypes in c:\users\jines\anaconda3\lib\site-packages (from pyttsx3) (1.1.10)

# %%
result = recognize_text(im_1_path)

sentence = ''
for (bbox, text, prob) in result:
    sentence += f'{text} '
print(sentence)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# CCC444

# %%
import pyttsx3

engine = pyttsx3.init()
engine.setProperty('rate', 100)
engine.say(sentence)
engine.runAndWait()

# %%
result = recognize_text(im_2_path)

sentence = ''
for (bbox, text, prob) in result:
    sentence += f'{text} '
print(sentence)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# 5

# %%
import pyttsx3

engine = pyttsx3.init()
engine.setProperty('rate', 100)
engine.say(sentence)
engine.runAndWait()
